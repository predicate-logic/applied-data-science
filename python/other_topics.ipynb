# %% [markdown]
# # Other Topics

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Double-resolution for Mac Retina Displays

# %%
# %config InlineBackend.figure_format = 'retina'

x = range(-1000, 1000)
y = [i**2 for i in x]
plt.plot(x,y)
plt.show();
